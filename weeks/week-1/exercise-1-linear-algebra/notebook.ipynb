# %% [markdown]
# # Exercise 1 — Word Embeddings
#
# Load vectors for `king`, `queen`, `dog`, `cat`, and `coffee`, then compute pairwise distances.

# %%
# Example direction:
# import gensim.downloader as api
# model = api.load('word2vec-google-news-300')
# words = ['king', 'queen', 'dog', 'cat', 'coffee']
